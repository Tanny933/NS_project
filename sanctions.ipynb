# %%
import networkx as nx
import pandas as pd
import numpy as np
import os

# %%
All=['Aruba', 'United Kingdom', 'Curaçao', 'Netherlands', 'Colombia', 'Panama', 'United States', 'Venezuela', 'Germany', 'France', 'China', 'Ireland', 'Belgium', 'Mexico', 'Brazil', 'Spain', 'Ecuador', 'Costa Rica', 'Singapore', 'Free Zones', 'Japan', 'Canada', 'Afghanistan', 'India', 'Iraq', 'Kazakhstan', 'Pakistan', 'Uzbekistan', 'Iran, Islamic Rep.', 'Turkey', 'United Arab Emirates', 'Hong Kong, China', 'Switzerland', 'Saudi Arabia', 'Russian Federation', 'Italy', 'Korea, Rep.', 'Other Asia, nes', 'Indonesia', 'Angola', 'South Africa', 'Portugal', 'Botswana', 'Argentina', 'Albania', 'Greece', 'Malta', 'Serbia, FR(Serbia/Montenegro)', 'Bulgaria', 'Cyprus', 'Egypt, Arab Rep.', 'Bunkers', 'Cayman Islands', 'Romania', 'Bosnia and Herzegovina', 'Hungary', 'Andorra', 'Norway', 'Sweden', 'Denmark', 'Vietnam', 'Chile', 'Thailand', 'Armenia', 'Georgia', 'Belarus', 'Azerbaijan', 'Antigua and Barbuda', 'Barbados', 'Special Categories', 'Australia', 'Guyana', 'Trinidad and Tobago', 'Malaysia', 'Austria', 'Czech Republic', 'Poland', 'Slovak Republic', 'Israel', 'Burundi', 'Kenya', 'Tanzania', 'Uganda', 'Congo, Dem. Rep.', 'Rwanda', 'South Sudan', 'Benin', 'Nigeria', 'Togo', 'Bangladesh', "Cote d'Ivoire", 'Ghana', 'Burkina Faso', 'Mali', 'Niger', 'Bahrain', 'Qatar', 'Bahamas, The', 'Turks and Caicos Isl.', 'Croatia', 'Slovenia', 'Ukraine', 'Belize', 'Jamaica', 'Guatemala', 'El Salvador', 'Nicaragua', 'Honduras', 'Bermuda', 'Bolivia', 'Peru', 'Suriname', 'Gabon', 'Brunei', 'Namibia', 'Zambia', 'Central African Republic', 'Cameroon', 'Congo, Rep.', 'Heard Island and McDonald Isla', 'Comoros', 'Mauritius', 'Madagascar', 'Cape Verde', 'Liberia', 'Finland', 'Dominican Republic', 'Haiti', 'Algeria', 'Estonia', 'Lithuania', 'Latvia', 'Ethiopia(excludes Eritrea)', 'Kuwait', 'European Union', 'Fiji', 'New Zealand', 'Guinea', 'Gambia, The', 'Senegal', 'Guinea-Bissau', 'Grenada', 'Greenland', 'Iceland', 'Jordan', 'Kyrgyz Republic', 'Cambodia', 'Kiribati', 'East Timor', 'St. Kitts and Nevis', 'St. Lucia', 'Lebanon', 'Syrian Arab Republic', 'Libya', 'Sri Lanka', 'Lesotho', 'Eswatini', 'Mozambique', 'Luxembourg', 'Macao', 'Morocco', 'Moldova', 'Maldives', 'North Macedonia', 'Myanmar', 'Mongolia', 'Montenegro', 'Mauritania', 'Montserrat', 'Anguila', 'British Virgin Islands', 'Malawi', 'Nepal', 'Oman', 'Philippines', 'Palau', 'Guam', 'Paraguay', 'Occ.Pal.Terr', 'French Polynesia', 'Solomon Islands', 'Sierra Leone', 'Sao Tome and Principe', 'Sudan', 'Seychelles', 'Tajikistan', 'Turkmenistan', 'Tunisia', 'Uruguay', 'St. Vincent and the Grenadines', 'Dominica', 'Samoa', 'American Samoa', 'Zimbabwe']

# %%
North_Am=['Aruba', 'Curaçao', 'Panama', 'United States', 'Venezuela', 'Canada', 'Mexico', 'Antigua and Barbuda', 'Barbados', 'Bahamas, The', 'Turks and Caicos Isl.', 'Cayman Islands', 'Bermuda', 'Jamaica', 'Guatemala', 'El Salvador', 'Nicaragua', 'Honduras', 'Dominican Republic', 'Haiti', 'Cuba', 'Costa Rica', 'Trinidad and Tobago', 'Guyana', 'Suriname', 'Belize', 'St. Kitts and Nevis', 'St. Lucia', 'Dominica', 'St. Vincent and the Grenadines', 'Grenada', 'Antigua and Barbuda', 'St. Vincent and the Grenadines']

Europe=['United Kingdom', 'Netherlands', 'Germany', 'France', 'Ireland', 'Belgium', 'Spain', 'Switzerland', 'Italy', 'Norway', 'Sweden', 'Denmark', 'Portugal', 'Romania', 'Bosnia and Herzegovina', 'Hungary', 'Andorra', 'Finland', 'Serbia, FR(Serbia/Montenegro)', 'Bulgaria', 'Cyprus', 'Belarus', 'Latvia', 'Lithuania', 'Estonia', 'Moldova', 'North Macedonia', 'Luxembourg', 'Malta', 'San Marino', 'Monaco', 'Liechtenstein', 'Holy See']

Asia=['China', 'Hong Kong, China', 'Turkey', 'United Arab Emirates', 'Korea, Rep.', 'Japan', 'Singapore', 'Iran, Islamic Rep.', 'Vietnam', 'Malaysia', 'Israel', 'Kazakhstan', 'Pakistan', 'Uzbekistan', 'Iraq', 'Thailand', 'Azerbaijan', 'Georgia', 'Armenia', 'Qatar', 'Lebanon', 'Oman', 'Kuwait', 'Jordan', 'Yemen, Rep.', 'Syrian Arab Republic', 'Tajikistan', 'Kyrgyz Republic', 'Turkmenistan', 'Bahrain', 'Afghanistan']
South_Am=['Colombia', 'Ecuador', 'Brazil', 'Argentina', 'Chile', 'Peru', 'Bolivia', 'Paraguay', 'Uruguay', 'Guyana', 'Suriname', 'Venezuela']
Africa=['South Africa', 'Angola', 'Nigeria', 'Tanzania', 'Kenya', 'Uganda', 'Congo, Dem. Rep.', 'Sudan', 'Ethiopia(excludes Eritrea)', 'Egypt, Arab Rep.', 'Ghana', "Cote d'Ivoire", 'Madagascar', 'Cameroon', 'Zambia', 'Niger', 'Mozambique', 'Morocco', 'Uzbekistan', 'Mali', 'Burkina Faso', 'Mauritania', 'Somalia', 'Central African Republic', 'Nepal', 'Chad', 'Zimbabwe', 'Botswana', 'Rwanda', 'Tunisia', 'Senegal', 'South Sudan', 'Gambia, The', 'Namibia', 'Eswatini', 'Lesotho', 'Guinea', 'Burundi', 'Sierra Leone', 'Togo', 'Libya', 'Djibouti', 'Guinea-Bissau', 'Equatorial Guinea', 'Comoros', 'Mauritius', 'Western Sahara', 'Cape Verde', 'Sao Tome and Principe', 'Seychelles', 'Eritrea', 'Saint Helena']
Oceania=['Australia', 'New Zealand', 'Guam', 'French Polynesia', 'Fiji', 'Papua New Guinea', 'New Caledonia', 'Solomon Islands', 'Vanuatu', 'Samoa', 'Marshall Islands', 'Federated States of Micronesia', 'Palau', 'Kiribati', 'Tuvalu', 'Nauru', 'Cook Islands', 'Niue', 'Tokelau', 'American Samoa', 'Wallis and Futuna', 'Norfolk Island', 'Guam']

# %%
def undirected(year):
    G=nx.Graph()
    df=pd.read_csv(f"graphs/{year}.csv")
    for index, row in df.iterrows():
        source=row["source"]
        target=row["target"]
        weight=float(row[f"{year}"])
        if G.has_edge(row["source"],row["target"]):
            G[source][target]['weight']+=weight
        else:

            G.add_edge(source,target,weight=weight)

    return G

# %%
def find_top(G,country,retain):
    neighbors = [n for n in list(G.neighbors(country)) if n not in retain]

    # Sort neighbors based on edge weights
    neighbors_sorted = sorted(neighbors, key=lambda n: float(G[country][n]['weight']), reverse=True)

    # Get top 5 nodes with highest edge weights
    top_nodes = neighbors_sorted[:10]


    return top_nodes

# %%
All_prods={}
for i in range (1993,2022):
    All_prods[i]={}

# %%
def build_dict(year):
   
    for filename in os.listdir("wits_en_trade_summary_allcountries_allyears"):
        df1=pd.read_csv(f"wits_en_trade_summary_allcountries_allyears/{filename}",encoding='latin-1')
        if len(df1)!=0:
            df1_1=df1[['Reporter','Partner','Product categories','Indicator Type','Indicator',str(year)]].dropna()
           
            df1_1=df1_1[df1_1['Partner']=='World']
            df1_1=df1_1[df1_1['Indicator Type']=='Export']
            df1_1=df1_1[df1_1['Indicator']=='Export(US$ Mil)']
            
            df1_1=df1_1[df1_1['Product categories']!='All products']
            df1
            # print(df1_1)
            for index,row in df1_1.iterrows():
                
                if row['Product categories'] not in All_prods[year]:
                    if float(row[str(year)])>5000:
                        All_prods[year][row['Product categories']]=[(row['Reporter'],float(row[str(year)]))]
                else:
                        if float(row[str(year)])>5000:
                            All_prods[year][row['Product categories']].append((row['Reporter'],float(row[str(year)])))

# %%
for i in range(1993,2022):
    build_dict(i)

# %%
(All_prods[2015]['Consumer goods'])
# Out:
# [('United Arab Emirates', 64114.38),
#  ('Argentina', 9673.87),
#  ('Australia', 27765.37),
#  ('Austria', 46376.41),
#  ('Belgium', 99787.09),
#  ('Bangladesh', 29643.83),
#  ('Bulgaria', 9646.08),
#  ('Bahrain', 8145.27),
#  ('Belarus', 12142.16),
#  ('Brazil', 24130.49),
#  ('Canada', 117840.69),
#  ('Switzerland', 95364.41),
#  ('Chile', 6390.56),
#  ('China', 858718.07),
#  ('Colombia', 7417.41),
#  ('Czech Republic', 62422.45),
#  ('Germany', 476147.69),
#  ('Denmark', 31993.39),
#  ('Algeria', 21105.18),
#  ('Egypt, Arab Rep.', 10266.77),
#  ('Spain', 121166.61),
#  ('Estonia', 5294.38),
#  ('European Union', 699477.73),
#  ('Finland', 12283.22),
#  ('France', 179449.53),
#  ('United Kingdom', 170288.17),
#  ('Greece', 15965.0),
#  ('Hong Kong, China', 86278.12),
#  ('Croatia', 5564.34),
#  ('Hungary', 38127.69),
#  ('Indonesia', 60519.56),
#  ('India', 117642.97),
#  ('Ireland', 41115.35),
#  ('Iran, Islamic Rep.', 19006.43),
#  ('Israel', 13579.56),
#  ('Italy', 195528.18),
#  ('Japan', 157034.4),
#  ('Cambodia', 7655.02),
#  ('Korea, Rep.', 118523.52),
#  ('Kuwait', 16005.64),
#  ('Sri Lanka', 8186.52),
#  ('Lithuania', 12669.01),
#  ('Morocco', 10569.12),
#  ('Mexico', 111241.91),
#  ('Myanmar', 6320.37),
#  ('Malaysia', 65065.69),
#  ('Nigeria', 8678.83),
#  ('Netherlands', 165246.89),
#  ('Norway', 39317.36),
#  ('New Zealand', 8397.54),
#  ('Other Asia, nes', 53152.23),
#  ('Oman', 10643.43),
#  ('Pakistan', 12726.15),
#  ('Panama', 7543.73),
#  ('Peru', 5852.39),
#  ('Philippines', 12869.41),
#  ('Poland', 88240.89),
#  ('Portugal', 27802.69),
#  ('Romania', 24394.43),
#  ('Russian Federation', 131112.86),
#  ('Saudi Arabia', 29416.64),
#  ('Serbia, FR(Serbia/Montenegro)', 6506.62),
#  ('Singapore', 85890.62),
#  ('Slovak Republic', 36995.42),
#  ('Slovenia', 12212.76),
#  ('Sweden', 44258.54),
#  ('Thailand', 75041.94),
#  ('Tunisia', 6812.57),
#  ('Turkey', 70373.13),
#  ('Ukraine', 6064.57),
#  ('United States', 388367.79),
#  ('Vietnam', 66257.88),
#  (' World', 5852849.17),
#  ('South Africa', 18625.76)]

# %%
def find_exports(country,year):
    exports=[]
    for filename in os.listdir("wits_en_trade_summary_allcountries_allyears"):
        df1=pd.read_csv(f"wits_en_trade_summary_allcountries_allyears/{filename}",encoding='latin-1')
        if len(df1)==0 or df1.iloc[0]['Reporter']!=country:
            continue
        else:
            df1_1=df1[['Reporter','Partner','Product categories','Indicator Type','Indicator',str(year)]].dropna()
           
            df1_1=df1_1[df1_1['Partner']=='World']
            df1_1=df1_1[df1_1['Indicator Type']=='Export']
            df1_1=df1_1[df1_1['Indicator']=='Export(US$ Mil)']
            
            df1_1=df1_1[df1_1['Product categories']!='All products']
            # print(df1_1)
            for index,row in df1_1.iterrows():
                if float(row[str(year)])>5000:
                    exports.append((row['Product categories'],float(row[str(year)])))
            
            return exports

# %%
len(find_exports("India",2015))
# Out:
# [('Consumer goods', 117642.97), ('Raw materials', 21825.4), ('Capital goods', 36526.26), ('Vegetable', 16753.81), ('Intermediate goods', 86076.37), ('Textiles and Clothing', 37161.71), ('Transportation', 22013.91), ('Mach and Elec', 21165.34), ('Metals', 21239.36), ('Stone and Glass', 41417.64), ('Fuels', 31393.7), ('Chemicals', 32722.03)]
# 12

# %%
def sanction(country,year):
    G=undirected(year)
    
    print(list(G.neighbors(country)))
    retain=[i for i in input("Enter Countries you want to retain:").split(",")]
    print(f"Countries affected directly: {len(list(G.neighbors(country)))-len(retain)}")
    print(find_top(G,country,retain))
    degree_centrality = nx.degree_centrality(G)[country]
    closeness_centrality = nx.closeness_centrality(G)[country]
    betweenness_centrality = nx.betweenness_centrality(G)[country]
    
    exports=find_exports(country,year)
    Tot_trade=sum([G[country][n]['weight'] for n in list(G.neighbors(country)) if n not in retain])
    print("Total trade deficit(US$ Million): ",Tot_trade)
    total_weight = sum(weight for _, _, weight in G.edges(data='weight', default=1))
    print("Total trade deficit %: ",Tot_trade/total_weight * 100)

    for n in list(G.neighbors(country)):
        if n not in retain:
            G.remove_edge(country,n)
    
    degree_centrality1 = nx.degree_centrality(G)[country]
    closeness_centrality1 = nx.closeness_centrality(G)[country]
    betweenness_centrality1 = nx.betweenness_centrality(G)[country]
    print(f"\t\t\t\tBefore\tAfter\nDegree_centrality {degree_centrality}\t{degree_centrality1}\nCloseness_centrality {closeness_centrality}\t {closeness_centrality1}\nBetweenness_centrality {betweenness_centrality}\t {betweenness_centrality1}")

    for export in exports:
        print("\n")
        top_alts = sorted(All_prods[year][export[0]], key=lambda x: x[1], reverse=True)
        print(f"Top alternatives for {export[0]}")
        for i in top_alts[1:10]:
            print(i[0],":",i[1])

# %%
sanction("France",2016)
# Out:
# ['United Kingdom', 'Netherlands', 'Portugal', 'Germany', 'Malta', 'Italy', 'Andorra', 'Norway', 'China', 'Spain', 'United States', 'Belgium', 'Switzerland', 'Russian Federation', 'Austria', 'Czech Republic', 'Azerbaijan', 'Benin', 'Nigeria', 'Togo', 'Burkina Faso', "Cote d'Ivoire", 'Romania', 'Bahamas, The', 'Slovenia', 'Poland', 'Ireland', 'Central African Republic', 'Cameroon', 'Comoros', 'Mauritius', 'Slovak Republic', 'Algeria', 'Guinea', 'Senegal', 'Hungary', 'Libya', 'Luxembourg', 'Macao', 'Morocco', 'Madagascar', 'Maldives', 'Mali', 'Montserrat', 'Niger', 'French Polynesia', 'Seychelles', 'Tunisia']
# Countries affected directly: 47
# ['Germany', 'Italy', 'Spain', 'Belgium', 'United Kingdom', 'China', 'United States', 'Netherlands', 'Switzerland', 'Ireland']
# Total trade deficit(US$ Million):  742438.5
# Total trade deficit %:  7.015810525341032
# 				Before	After
# Degree_centrality 0.24870466321243523	0.0
# Closeness_centrality 0.5376044568245125	 0.0
# Betweenness_centrality 0.026526945610702124	 0.0
#
#
# Top alternatives for Consumer goods
# China : 785488.82
# European Union : 683067.38
# Germany : 477193.32
# United States : 370436.52
# Italy : 197836.2
# France : 179770.0
# Netherlands : 167160.29
# Japan : 164965.01
# United Kingdom : 160956.47
#
#
# Top alternatives for Raw materials
# United States : 136670.47
# Saudi Arabia : 114163.85
# Australia : 107027.96
# Russian Federation : 102864.91
# Canada : 82302.37
# European Union : 79393.97
# Brazil : 73139.31
# Netherlands : 43978.15
# Iran, Islamic Rep. : 40561.98
#
#
# Top alternatives for Capital goods
# China : 927319.15
# European Union : 715342.14
# Germany : 517828.23
# United States : 498512.9
# Hong Kong, China : 320128.86
# Japan : 305051.68
# Korea, Rep. : 268021.69
# France : 179564.13
# Mexico : 176882.57
#
#
# Top alternatives for Plastic or Rubber
# China : 81401.27
# European Union : 74357.93
# United States : 71655.24
# Germany : 71366.64
# Korea, Rep. : 34552.91
# Japan : 33267.0
# Netherlands : 25989.03
# Thailand : 23818.97
# France : 23816.61
#
#
# Top alternatives for Vegetable
# United States : 72138.16
# European Union : 34896.71
# Netherlands : 33498.57
# Brazil : 31299.86
# China : 25031.3
# Indonesia : 23929.19
# Canada : 23147.57
# Spain : 23054.29
# Argentina : 18336.64
#
#
# Top alternatives for Miscellaneous
# China : 224809.43
# European Union : 195966.48
# United States : 168832.29
# United Arab Emirates : 146277.07
# Germany : 142229.42
# Japan : 89851.17
# Netherlands : 47626.29
# Russian Federation : 45494.27
# United Kingdom : 44221.56
#
#
# Top alternatives for Intermediate goods
# European Union : 380894.4
# China : 342021.55
# United States : 284221.32
# Germany : 244846.22
# Switzerland : 149345.21
# Japan : 127835.1
# Korea, Rep. : 112578.51
# Hong Kong, China : 107298.35
# Canada : 97936.86
#
#
# Top alternatives for Textiles and Clothing
# China : 253292.36
# European Union : 49456.69
# India : 35429.24
# Italy : 32238.1
# Germany : 31713.29
# Vietnam : 28705.7
# Turkey : 27025.65
# United States : 23649.31
# Hong Kong, China : 22798.68
#
#
# Top alternatives for Food Products
# European Union : 79474.77
# United States : 43759.55
# Germany : 42195.97
# Netherlands : 35158.05
# France : 33132.34
# China : 28543.5
# Brazil : 24432.65
# Italy : 24026.5
# United Kingdom : 18461.5
#
#
# Top alternatives for Transportation
# European Union : 326253.37
# Germany : 299954.68
# United States : 265253.1
# Japan : 161100.42
# France : 102599.98
# Korea, Rep. : 98232.51
# China : 92882.01
# Mexico : 92408.14
# Canada : 75088.66
#
#
# Top alternatives for Hides and Skins
# China : 31396.64
# European Union : 17325.6
# Italy : 12834.52
# France : 7591.25
# Hong Kong, China : 6546.9
#
#
# Top alternatives for Wood
# European Union : 47568.47
# China : 37908.96
# United States : 37718.14
# Germany : 34991.18
# Canada : 27658.12
# Sweden : 14913.13
# Finland : 12671.68
# France : 11066.43
# Italy : 10658.83
#
#
# Top alternatives for Mach and Elec
# China : 895639.75
# European Union : 485542.12
# Germany : 352352.14
# United States : 348417.45
# Hong Kong, China : 320074.92
# Japan : 212887.47
# Korea, Rep. : 190935.61
# Singapore : 159375.01
# Other Asia, nes : 153697.21
#
#
# Top alternatives for Metals
# China : 154383.51
# European Union : 104207.69
# Germany : 95074.69
# United States : 63728.28
# Japan : 48989.85
# Korea, Rep. : 42264.67
# Italy : 41459.9
# France : 29571.97
# Russian Federation : 28983.45
#
#
# Top alternatives for Stone and Glass
# Switzerland : 99070.86
# Hong Kong, China : 86957.96
# European Union : 83208.08
# United States : 68595.29
# China : 66009.55
# India : 45331.27
# United Arab Emirates : 43511.79
# United Kingdom : 31332.22
# Germany : 26963.39
#
#
# Top alternatives for Fuels
# Russian Federation : 145734.67
# Saudi Arabia : 136216.8
# United States : 94005.49
# European Union : 82821.32
# Canada : 62277.47
# Netherlands : 56385.46
# Iran, Islamic Rep. : 56204.18
# Australia : 48540.0
# United Arab Emirates : 47553.96
#
#
# Top alternatives for Chemicals
# European Union : 301636.6
# Germany : 165086.96
# United States : 153095.74
# China : 99163.17
# Switzerland : 93191.96
# Ireland : 73145.51
# France : 72792.69
# United Kingdom : 61972.28
# Belgium : 59643.73
#
#
# Top alternatives for Animal
# European Union : 30330.98
# United States : 25328.57
# Netherlands : 22340.58
# Germany : 21622.89
# China : 17616.69
# Brazil : 13900.01
# New Zealand : 13727.49
# France : 13606.78
# Australia : 12458.92
